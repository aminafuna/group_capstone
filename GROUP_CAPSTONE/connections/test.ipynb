# %%
Hello_Word = lambda x: x; Hello_Word("print")
# Out:
# 'print'

# %%
import matplotlib.pyplot as plt, cv2

img = cv2.imread(r"/home/zkllmt/Documents/For_Finals_2nd_Year_2nd_Sem/group_capstone/GROUP_CAPSTONE/static/img/tryy.webp")
img = cv2.resize(img, (500, 500))
plt.imshow(img[:,:,::-1])
plt.axis("off")
plt.savefig("product-9.jpg")
plt.show()
display(img.shape)
# Out:
# (500, 500, 3)

# %%
ss = cv2.imread(r"/home/zkllmt/Documents/For_Finals_2nd_Year_2nd_Sem/group_capstone/GROUP_CAPSTONE/static/img/product-2.jpg")

ss.shape
# Out:
# (500, 500, 3)
